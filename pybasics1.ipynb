# %%
print("hello")
# Out:
# hello

# %%
name="sridhar"
print(name)
# Out:
# sridhar

# %%
1name='sri'
print(1name)
# Out:
#   Cell In[2], line 1
#     1name='sri'
#     ^
# SyntaxError: invalid decimal literal

# %%
name@='sri'
print(name@)
# Out:
#   Cell In[3], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax
